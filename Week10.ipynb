# %% [markdown]
# <a href="https://colab.research.google.com/github/MarkL005/ThinkPythonAssignments/blob/main/Week10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Mark Lucas
# Intro to Programming with Python
# Week Assignment
# Team List Program

# Create a function to add a player to the team list
# Parameter: team_list, player_name
# Add the player name to the list

# Create a function to check if a player is on the team list
# Parameter: team_list, player_name
# If player name is in the list
#     print that the player is on the team
# Else
#     print that the player is not on the team

# Create an empty team list

# Ask the user how many players they want to enter

# Use a loop to ask for each player name
# Call the add player function each time

# Ask the user for a player name to search for

# Call the search function

# Print the full team list
