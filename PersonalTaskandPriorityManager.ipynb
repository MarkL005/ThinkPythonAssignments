# %% [markdown]
# <a href="https://colab.research.google.com/github/MarkL005/ThinkPythonAssignments/blob/main/PersonalTaskandPriorityManager.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Personal Task and Priority Manager
# STRUCTURE & PSEUDOCODE

# IMPORT STATEMENTS
# No imports needed for the basic Google Colab version

# FUNCTION DEFINITIONS

# Create an empty list to store tasks

# Function: add_task
# Ask the user for task name
# Ask the user for priority
# Ask the user for due date
# Store the task in a dictionary
# Add the task dictionary to the task list

# Function: view_tasks
# If there are no tasks, tell the user
# Otherwise, loop through the task list
# Print each task with its priority, due date, and status

# Function: mark_complete
# Show all tasks
# Ask the user which task they finished
# Change that task's completed status to True

# Function: delete_task
# Show all tasks
# Ask the user which task to delete
# Remove that task from the list

# PROGRAM LOGIC

# Show a menu with options:
# 1. Add task
# 2. View tasks
# 3. Mark task complete
# 4. Delete task
# 5. Exit

# Keep showing the menu until the user chooses Exit
