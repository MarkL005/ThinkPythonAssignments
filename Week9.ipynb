# %% [markdown]
# <a href="https://colab.research.google.com/github/MarkL005/ThinkPythonAssignments/blob/main/Week9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ************************************************************
# Name: Mark Lucas
# Course: Intro to Python Programming
# Assignment: Midterm Project - Rental Car Pricing System
# Purpose: Calculate a customer's rental car bill based on
# car class, rental days, and miles driven.
# ************************************************************

# -------------------------
# Import Statements
# -------------------------

# No imports are needed for this program.

# -------------------------
# Function Definitions
# -------------------------

# Define a function named calculate_bill that accepts:
# - car code
# - rental days
# - starting odometer reading
# - ending odometer reading

# Inside the function:
# 1. Calculate miles driven by subtracting the starting odometer
#    from the ending odometer.
# 2. Determine the daily rate based on the car code.
#    B = Budget
#    S = Standard
#    L = Luxury
# 3. Determine the full class name based on the car code.
# 4. If miles driven is greater than 100, calculate charged miles.
#    Otherwise charged miles is 0.
# 5. Calculate the mileage charge by multiplying charged miles by 0.35.
# 6. Calculate the base rental cost by multiplying rental days by daily rate.
# 7. Add base rental cost and mileage charge to get total bill.
# 8. Return total bill, miles driven, charged miles, and class name.

# -------------------------
# Main Program
# -------------------------

# Display a welcome message.

# Ask the user to enter a car classification code.

# Use a loop to validate the code.
# Keep asking until the user enters B, S, or L.

# Ask the user to enter the number of rental days.

# Ask the user to enter the starting odometer reading.

# Ask the user to enter the ending odometer reading.

# Call the calculate_bill function and pass in the user input.

# Store the returned values.

# Display the final rental summary:
# - full car class name
# - miles driven
# - charged miles
# - total bill
