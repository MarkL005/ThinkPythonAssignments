# %% [markdown]
# <a href="https://colab.research.google.com/github/MarkL005/ThinkPythonAssignments/blob/main/Week6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
import math

# FUNCTION DEFINITIONS
def circle_area(radius):
    return math.pi * radius**2

def circle_circumference(radius):
    return 2 * math.pi * radius

def cylinder_volume(radius, height):
    return circle_area(radius) * height

# PROGRAM LOGIC
radius = float(input("Enter the radius: "))

area = circle_area(radius)
circ = circle_circumference(radius)

print("Circle area:", str(area))
print("Circle circumference:", str(circ))

height = float(input("Enter the height: "))

volume = cylinder_volume(radius, height)
print("Cylinder volume:", str(volume))
