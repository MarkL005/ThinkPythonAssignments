# %% [markdown]
# <a href="https://colab.research.google.com/github/MarkL005/ThinkPythonAssignments/blob/main/Week3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS

# FUNCTION DEFINITIONS

# PROGRAM LOGIC
# Assign values to name, goal, birth year, and current year
# Calculate age using current year minus birth year
# Print top border using string repetition
# Print bio sentences using variables
# Print bottom border using string repetition
