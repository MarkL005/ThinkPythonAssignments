# %% [markdown]
# <a href="https://colab.research.google.com/github/MarkL005/ThinkPythonAssignments/blob/main/Week3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS

# FUNCTION DEFINITIONS

# PROGRAM LOGIC

# Assign values to variables
name = "Mark Lucas"
goal = "become a cybersecurity analyst"
birth_year = 2003
current_year = 2026

# Calculate age
age = current_year - birth_year

# Print top border
print("=" * 25)

# Print bio
print("My name is " + name + ".")
print("I am " + str(age) + " years old.")
print("My goal is to " + goal + ".")

# Print bottom border
print("=" * 25)
# Out:
# ...
# My name is Mark Lucas.
# I am 23 years old.
# My goal is to become a cybersecurity analyst.
# ...
