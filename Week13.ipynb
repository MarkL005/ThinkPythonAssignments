# %% [markdown]
# <a href="https://colab.research.google.com/github/MarkL005/ThinkPythonAssignments/blob/main/Week13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Mark Lucas
# Chapter 13 Journal Program

# IMPORT STATEMENTS


# FUNCTION DEFINITIONS

def write_entry():
    # ask user for a journal entry
    # open journal file in append mode
    # write the entry to the file
    # add a new line character


def read_journal():
    # try to open the journal file in read mode
    # read all contents from the file
    # display the journal contents
    # if the file does not exist, show a message


# PROGRAM LOGIC

# loop until the user chooses to quit
# ask the user to type W to write, R to read, or Q to quit
# if the user types W, call write_entry
# if the user types R, call read_journal
# if the user types Q, end the program
# otherwise show an invalid choice message
# Out:
#   File "/tmp/ipykernel_1379/3242465527.py", line 16
#     def read_journal():
#     ^
# IndentationError: expected an indented block after function definition on line 9
