# %% [markdown]
# <a href="https://colab.research.google.com/github/MarkL005/ThinkPythonAssignments/blob/main/Week16FinalProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Final Project: Expense Tracker
# Name: Mark Lucas

# FUNCTIONS

# function to add an expense
# ask user for category
# ask for vendor
# ask for amount
# ask for date
# create a dictionary with that info
# add it to the list

# function to show one expense
# print date, category, vendor, amount

# function to show all expenses
# if list is empty say no expenses
# loop through list and print each one
# add up total and print total

# function to search by category
# ask user for category
# loop through list
# if category matches print it
# keep total
# print total at end

# function to search by vendor
# ask user for vendor
# loop through list
# if vendor matches print it
# keep total
# print total at end

# reports menu
# give options for all, category, vendor, back

# main menu
# create empty list
# option to add expense
# option for reports
# option to quit
# loop until quit

# PROGRAM STARTS HERE
