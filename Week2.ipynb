# %% [markdown]
# <a href="https://colab.research.google.com/github/MarkL005/ThinkPythonAssignments/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# No imports are needed for this program


# FUNCTION DEFINITIONS
# No functions are needed for this program


# PROGRAM LOGIC

# Calculate and print the total minutes in the movie
print("Total minutes in movie: " + str(2 * 60 + 45))

# Calculate and print the number of years since the first computer bug
print("Years since first bug: " + str(2026 - 1947))

# Calculate and print the total cost of the books
print("Total cost of books: " + str(7 * 35))
# Out:
# Total minutes in movie: 165
# Years since first bug: 79
# Total cost of books: 245
