# %% [markdown]
# <a href="https://colab.research.google.com/github/MarkL005/ThinkPythonAssignments/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# No imports are needed for this program


# FUNCTION DEFINITIONS
# No functions are needed for this program


# PROGRAM LOGIC
# 1. Calculate the total number of minutes in a movie that is 2 hours and 45 minutes long
# 2. Calculate how many years have passed since the first computer bug in 1947
# 3. Calculate the total cost of buying 7 books that cost $35 each
# 4. Print the results so the user can see them
