# %% [markdown]
# <a href="https://colab.research.google.com/github/MarkL005/ThinkPythonAssignments/blob/main/Week4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# None needed for this program

# FUNCTION DEFINITIONS
def print_bio(name, age, goal):
    border = "=============================="
    print(border)
    print("Name: " + name)
    print("Age: " + str(age))
    print("Goal: " + goal)
    print(border)

# PROGRAM LOGIC
print_bio("Mark", 34, "Learn Python functions")

print_bio("Sarah", 21, "Become more confident with coding")

print_bio("Jason", 45, "Transition into an IT career")
# Out:
# ...
# Name: Mark
# Age: 34
# Goal: Learn Python functions
# ...
# Name: Sarah
# Age: 21
# Goal: Become more confident with coding
# ...
# Name: Jason
# Age: 45
# Goal: Transition into an IT career
# ...
