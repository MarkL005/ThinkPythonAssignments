# %% [markdown]
# <a href="https://colab.research.google.com/github/MarkL005/ThinkPythonAssignments/blob/main/Week4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# None needed for this program

# FUNCTION DEFINITIONS
# Define a function called print_bio
# The function should take in:
# - name
# - age
# - goal
# Inside the function:
# - Print a top border
# - Print the person's name
# - Print the person's age
# - Print the person's goal
# - Print a bottom border

# PROGRAM LOGIC
# Call the print_bio function three times
# Each call should use different values
