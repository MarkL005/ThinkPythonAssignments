# %% [markdown]
# <a href="https://colab.research.google.com/github/MarkL005/ThinkPythonAssignments/blob/main/Week14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# STRUCTURE & PSEUDOCODE

# IMPORT STATEMENTS
# No imports needed for this program

# CLASS DEFINITIONS
# Create a Book class with:
# - title
# - author
# - available

# METHODS
# - __init__ to set up title, author, and available
# - __str__ to print book information
# - checkout to mark book as checked out
# - return_book to mark book as available again

# PROGRAM LOGIC
# Create two Book objects
# Print both books
# Check out one book
# Print both books again
